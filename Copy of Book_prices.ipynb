# %%
import pandas as pd
import numpy as np


import warnings 
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-73fd4813-5d46-4beb-9fcd-e51865ea8c3b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-73fd4813-5d46-4beb-9fcd-e51865ea8c3b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data_Test.xlsx to Data_Test (1).xlsx

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-deff8c37-ea5d-4363-bdd8-575e9fc9124c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-deff8c37-ea5d-4363-bdd8-575e9fc9124c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data_Train.xlsx to Data_Train.xlsx

# %%
train_data = pd.read_excel('Data_Train.xlsx')
test_data = pd.read_excel('Data_Test (1).xlsx')

train_data.head(20)
# Out:
#                                                 Title  \
# 0                 The Prisoner's Gold (The Hunters 3)
# 1                  Guru Dutt: A Tragedy in Three Acts
# 2                        Leviathan (Penguin Classics)
# 3                  A Pocket Full of Rye (Miss Marple)
# 4          LIFE 70 Years of Extraordinary Photography
# 5   ChiRunning: A Revolutionary Approach to Effort...
# 6                          Death on the Nile (Poirot)
# 7   Yoga Your Home Practice Companion: A Complete ...
# 8             Karmayogi: A Biography of E. Sreedharan
# 9          The Iron King (The Accursed Kings, Book 1)
# 10  Battle for Sanskrit: Is Sanskrit Political or ...
# 11  Blockchain Revolution: How the Technology Behi...
# 12        Tai-Pan: The Second Novel of the Asian Saga
# 13  The Art of Shaolin Kung Fu: The Secrets of Kun...
# 14                                       Anil's Ghost
# 15  Superman: An Origin Story (DC Comics Super Her...
# 16                            My First Book of London
# 17           Naruto: Itachi's Story, Vol. 1: Daylight
# 18                            The Story of Philosophy
# 19  Introducing Data Science: Big Data, Machine Le...
#
#                                          Author  \
# 0                                Chris Kuzneski
# 1                                  Arun Khopkar
# 2                                 Thomas Hobbes
# 3                               Agatha Christie
# 4                               Editors of Life
# 5                                  Danny Dreyer
# 6                               Agatha Christie
# 7                 Sivananda Yoga Vedanta Centre
# 8                                   M S Ashokan
# 9                                 Maurice Druon
# 10                               Rajiv Malhotra
# 11                  Don Tapscott, Alex Tapscott
# 12                                James Clavell
# 13                                Wong Kiew Kit
# 14                             Michael Ondaatje
# 15                            Matthew K Manning
# 16               Charlotte Guillain, Roland Dry
# 17                                 Takashi Yano
# 18                                  Will Durant
# 19  Davy Cielen, Arno D.B. Meysman, Mohamed Ali
#
#                                Edition             Reviews  \
# 0              Paperback,– 10 Mar 2016  4.0 out of 5 stars
# 1               Paperback,– 7 Nov 2012  3.9 out of 5 stars
# 2              Paperback,– 25 Feb 1982  4.8 out of 5 stars
# 3               Paperback,– 5 Oct 2017  4.1 out of 5 stars
# 4              Hardcover,– 10 Oct 2006  5.0 out of 5 stars
# 5               Paperback,– 5 May 2009  4.5 out of 5 stars
# 6               Paperback,– 5 Oct 2017  4.4 out of 5 stars
# 7       Hardcover,– Import, 1 Mar 2018  4.7 out of 5 stars
# 8              Paperback,– 15 Dec 2015  4.2 out of 5 stars
# 9              Paperback,– 26 Mar 2013  4.0 out of 5 stars
# 10             Paperback,– 20 Jan 2017  4.9 out of 5 stars
# 11     Paperback,– Import, 14 Jun 2018  3.5 out of 5 stars
# 12              Paperback,– 1 Jul 1999  4.1 out of 5 stars
# 13             Paperback,– 15 Nov 2002  5.0 out of 5 stars
# 14              Paperback,– 1 Sep 2011  3.8 out of 5 stars
# 15             Paperback,– 26 Feb 2015  5.0 out of 5 stars
# 16              Hardcover,– 8 Mar 2018  5.0 out of 5 stars
# 17              Paperback,– 1 Nov 2016  4.9 out of 5 stars
# 18  Mass Market Paperback,– 1 Jan 1991  4.5 out of 5 stars
# 19                    Paperback,– 2016  4.3 out of 5 stars
#
#                  Ratings                                           Synopsis  \
# 0     8 customer reviews  THE HUNTERS return in their third brilliant no...
# 1    14 customer reviews  A layered portrait of a troubled genius for wh...
# 2     6 customer reviews  "During the time men live without a common Pow...
# 3    13 customer reviews  A handful of grain is found in the pocket of a...
# 4      1 customer review  For seven decades, "Life" has been thrilling t...
# 5     8 customer reviews  The revised edition of the bestselling ChiRunn...
# 6    72 customer reviews  Agatha Christie’s most exotic murder mystery\n...
# 7    16 customer reviews  Achieve a healthy body, mental alertness, and ...
# 8   111 customer reviews  Karmayogi is the dramatic and inspiring story ...
# 9      1 customer review  ‘This is the original game of thrones’ George ...
# 10  132 customer reviews  There is a new awakening in India that is chal...
# 11   17 customer reviews  THE DEFINITIVE BOOK ON HOW THE TECHNOLOGY BEHI...
# 12    4 customer reviews  Set in the turbulent days of the founding of H...
# 13    3 customer reviews  The Art of Shaolin Kung Fu is the ultimate gui...
# 14    5 customer reviews  Anil's Ghost transports us to Sri Lanka, a cou...
# 15    2 customer reviews  One day, an alien orphan crash-lands on Earth ...
# 16     1 customer review  London is one of the most exciting cities in t...
# 17   23 customer reviews  A new series of prose novels, straight from th...
# 18   76 customer reviews  A brilliant and concise account of the lives a...
# 19    5 customer reviews  Introducing Data Science explains vital data s...
#
#                                          Genre  \
# 0                   Action & Adventure (Books)
# 1                   Cinema & Broadcast (Books)
# 2                      International Relations
# 3                 Contemporary Fiction (Books)
# 4                        Photography Textbooks
# 5            Healthy Living & Wellness (Books)
# 6            Crime, Thriller & Mystery (Books)
# 7           Sports Training & Coaching (Books)
# 8        Biographies & Autobiographies (Books)
# 9                   Action & Adventure (Books)
# 10                               Asian History
# 11                             Banks & Banking
# 12                  Action & Adventure (Books)
# 13                               Asian History
# 14                  Action & Adventure (Books)
# 15                     Comics & Mangas (Books)
# 16  Children's Mysteries & Curiosities (Books)
# 17                                      Mangas
# 18       Biographies & Autobiographies (Books)
# 19                     Artificial Intelligence
#
#                             BookCategory    Price
# 0                     Action & Adventure   220.00
# 1   Biographies, Diaries & True Accounts   202.93
# 2                                 Humour   299.00
# 3              Crime, Thriller & Mystery   180.00
# 4               Arts, Film & Photography   965.62
# 5                                 Sports   900.00
# 6              Crime, Thriller & Mystery   224.00
# 7                                 Sports   836.00
# 8   Biographies, Diaries & True Accounts   130.00
# 9                     Action & Adventure   695.00
# 10       Language, Linguistics & Writing   373.00
# 11   Computing, Internet & Digital Media   309.00
# 12                    Action & Adventure   379.00
# 13                                Sports  1066.00
# 14                               Romance   381.22
# 15                       Comics & Mangas   287.00
# 16             Crime, Thriller & Mystery   162.00
# 17                       Comics & Mangas   587.00
# 18  Biographies, Diaries & True Accounts   291.00
# 19   Computing, Internet & Digital Media   352.00

# %%
# Out:
# Mounted at /content/drive

# %%
test_data.shape
# Out:
# (1560, 8)

# %%
train_data.shape
# Out:
# (6237, 9)

# %%
test_data.shape
# Out:
# (1560, 8)

# %%
train_data.describe(include='all')
# Out:
#                                           Title           Author  \
# count                                      6237             6237
# unique                                     5568             3679
# top     Casino Royale: James Bond 007 (Vintage)  Agatha Christie
# freq                                          4               69
# mean                                        NaN              NaN
# std                                         NaN              NaN
# min                                         NaN              NaN
# 25%                                         NaN              NaN
# 50%                                         NaN              NaN
# 75%                                         NaN              NaN
# max                                         NaN              NaN
#
#                        Edition             Reviews            Ratings  \
# count                     6237                6237               6237
# unique                    3370                  36                342
# top     Paperback,– 5 Oct 2017  5.0 out of 5 stars  1 customer review
# freq                        48                1375               1040
# mean                       NaN                 NaN                NaN
# std                        NaN                 NaN                NaN
# min                        NaN                 NaN                NaN
# 25%                        NaN                 NaN                NaN
# 50%                        NaN                 NaN                NaN
# 75%                        NaN                 NaN                NaN
# max                        NaN                 NaN                NaN
#
#                                                  Synopsis  \
# count                                                6237
# unique                                               5549
# top     A Tinkle Double Digest is two Tinkle Digests i...
# freq                                                    8
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                              Genre        BookCategory         Price
# count                         6237                6237   6237.000000
# unique                         345                  11           NaN
# top     Action & Adventure (Books)  Action & Adventure           NaN
# freq                           947                 818           NaN
# mean                           NaN                 NaN    560.707516
# std                            NaN                 NaN    690.110657
# min                            NaN                 NaN     25.000000
# 25%                            NaN                 NaN    249.180000
# 50%                            NaN                 NaN    373.000000
# 75%                            NaN                 NaN    599.000000
# max                            NaN                 NaN  14100.000000

# %%
test_data.describe(include='all')
# Out:
#                                                 Title           Author  \
# count                                            1560             1560
# unique                                           1521             1224
# top     The Five Greatest Warriors (Jack West Series)  Agatha Christie
# freq                                                3               18
#
#                        Edition             Reviews            Ratings  \
# count                     1560                1560               1560
# unique                    1259                  30                163
# top     Paperback,– 5 Oct 2017  5.0 out of 5 stars  1 customer review
# freq                        12                 376                288
#
#                                                  Synopsis  \
# count                                                1560
# unique                                               1519
# top     The end is approaching ... Can Jack West unrav...
# freq                                                    3
#
#                              Genre        BookCategory
# count                         1560                1560
# unique                         225                  11
# top     Action & Adventure (Books)  Action & Adventure
# freq                           236                 218

# %% [markdown]
# Therfore there is no missing values.

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6237 entries, 0 to 6236
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         6237 non-null   object
#  1   Author        6237 non-null   object
#  2   Edition       6237 non-null   object
#  3   Reviews       6237 non-null   object
#  4   Ratings       6237 non-null   object
#  5   Synopsis      6237 non-null   object
#  6   Genre         6237 non-null   object
#  7   BookCategory  6237 non-null   object
#  8   Price         6237 non-null   float64
# dtypes: float64(1), object(8)
# memory usage: 438.7+ KB

# %% [markdown]
# Data Cleaning

# %%
train_data['Ratings'] = train_data['Ratings'].str[0].astype('float64')
train_data['Reviews'] = train_data['Reviews'].str[0].astype('float64')

test_data['Ratings'] = test_data['Ratings'].str[0].astype('float64')
test_data['Reviews'] = test_data['Reviews'].str[0].astype('float64')

train_data.head()
# Out:
#                                         Title           Author  \
# 0         The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1          Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                Leviathan (Penguin Classics)    Thomas Hobbes
# 3          A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4  LIFE 70 Years of Extraordinary Photography  Editors of Life
#
#                    Edition  Reviews  Ratings  \
# 0  Paperback,– 10 Mar 2016      4.0      8.0
# 1   Paperback,– 7 Nov 2012      3.0      1.0
# 2  Paperback,– 25 Feb 1982      4.0      6.0
# 3   Paperback,– 5 Oct 2017      4.0      1.0
# 4  Hardcover,– 10 Oct 2006      5.0      1.0
#
#                                             Synopsis  \
# 0  THE HUNTERS return in their third brilliant no...
# 1  A layered portrait of a troubled genius for wh...
# 2  "During the time men live without a common Pow...
# 3  A handful of grain is found in the pocket of a...
# 4  For seven decades, "Life" has been thrilling t...
#
#                           Genre                          BookCategory   Price
# 0    Action & Adventure (Books)                    Action & Adventure  220.00
# 1    Cinema & Broadcast (Books)  Biographies, Diaries & True Accounts  202.93
# 2       International Relations                                Humour  299.00
# 3  Contemporary Fiction (Books)             Crime, Thriller & Mystery  180.00
# 4         Photography Textbooks              Arts, Film & Photography  965.62

# %%
test_data.head()
# Out:
#                                                Title                  Author  \
# 0         The Complete Sherlock Holmes: 2 Boxes sets  Sir Arthur Conan Doyle
# 1  Learn Docker - Fundamentals of Docker 18.x: Ev...     Gabriel N. Schenker
# 2                                           Big Girl          Danielle Steel
# 3  Think Python: How to Think Like a Computer Sci...         Allen B. Downey
# 4  Oxford Word Skills: Advanced - Idioms & Phrasa...           Redman Gairns
#
#                               Edition  Reviews  Ratings  \
# 0  Mass Market Paperback,– 1 Oct 1986      4.0      9.0
# 1     Paperback,– Import, 26 Apr 2018      5.0      1.0
# 2             Paperback,– 17 Mar 2011      5.0      4.0
# 3                    Paperback,– 2016      4.0      1.0
# 4             Paperback,– 26 Dec 2011      4.0      9.0
#
#                                             Synopsis  \
# 0  A collection of entire body of work of the She...
# 1  Enhance your software deployment workflow usin...
# 2  'Watch out, world. Here I come!'\nFor Victoria...
# 3  If you want to learn how to program, working w...
# 4  Learn and practise the verbs, prepositions and...
#
#                                         Genre  \
# 0                       Short Stories (Books)
# 1                 Operating Systems Textbooks
# 2                             Romance (Books)
# 3  Programming & Software Development (Books)
# 4                         Linguistics (Books)
#
#                           BookCategory
# 0            Crime, Thriller & Mystery
# 1  Computing, Internet & Digital Media
# 2                              Romance
# 3  Computing, Internet & Digital Media
# 4      Language, Linguistics & Writing

# %%
train_data.drop(columns=['Title', 'Author', 'Synopsis', 'Genre'], inplace=True)
test_data.drop(columns=['Title', 'Author', 'Synopsis', 'Genre'], inplace=True)
train_data.head()
# Out:
#                    Edition  Reviews  Ratings  \
# 0  Paperback,– 10 Mar 2016      4.0      8.0
# 1   Paperback,– 7 Nov 2012      3.0      1.0
# 2  Paperback,– 25 Feb 1982      4.0      6.0
# 3   Paperback,– 5 Oct 2017      4.0      1.0
# 4  Hardcover,– 10 Oct 2006      5.0      1.0
#
#                            BookCategory   Price
# 0                    Action & Adventure  220.00
# 1  Biographies, Diaries & True Accounts  202.93
# 2                                Humour  299.00
# 3             Crime, Thriller & Mystery  180.00
# 4              Arts, Film & Photography  965.62

# %%
test_data.head()
# Out:
#                               Edition  Reviews  Ratings  \
# 0  Mass Market Paperback,– 1 Oct 1986      4.0      9.0
# 1     Paperback,– Import, 26 Apr 2018      5.0      1.0
# 2             Paperback,– 17 Mar 2011      5.0      4.0
# 3                    Paperback,– 2016      4.0      1.0
# 4             Paperback,– 26 Dec 2011      4.0      9.0
#
#                           BookCategory
# 0            Crime, Thriller & Mystery
# 1  Computing, Internet & Digital Media
# 2                              Romance
# 3  Computing, Internet & Digital Media
# 4      Language, Linguistics & Writing

# %%
train_data['Edition type'] = train_data['Edition'].str.split('–').str[0].str.replace(',', '')
train_data['Edition year'] = train_data['Edition'].str.split(' ').str[-1]

test_data['Edition type'] = test_data['Edition'].str.split('–').str[0].str.replace(',', '')
test_data['Edition year'] = test_data['Edition'].str.split(' ').str[-1]

train_data.head()
# Out:
#                    Edition  Reviews  Ratings  \
# 0  Paperback,– 10 Mar 2016      4.0      8.0
# 1   Paperback,– 7 Nov 2012      3.0      1.0
# 2  Paperback,– 25 Feb 1982      4.0      6.0
# 3   Paperback,– 5 Oct 2017      4.0      1.0
# 4  Hardcover,– 10 Oct 2006      5.0      1.0
#
#                            BookCategory   Price Edition type Edition year
# 0                    Action & Adventure  220.00    Paperback         2016
# 1  Biographies, Diaries & True Accounts  202.93    Paperback         2012
# 2                                Humour  299.00    Paperback         1982
# 3             Crime, Thriller & Mystery  180.00    Paperback         2017
# 4              Arts, Film & Photography  965.62    Hardcover         2006

# %%
test_data.head()
# Out:
#                               Edition  Reviews  Ratings  \
# 0  Mass Market Paperback,– 1 Oct 1986      4.0      9.0
# 1     Paperback,– Import, 26 Apr 2018      5.0      1.0
# 2             Paperback,– 17 Mar 2011      5.0      4.0
# 3                    Paperback,– 2016      4.0      1.0
# 4             Paperback,– 26 Dec 2011      4.0      9.0
#
#                           BookCategory           Edition type Edition year
# 0            Crime, Thriller & Mystery  Mass Market Paperback         1986
# 1  Computing, Internet & Digital Media              Paperback         2018
# 2                              Romance              Paperback         2011
# 3  Computing, Internet & Digital Media              Paperback         2016
# 4      Language, Linguistics & Writing              Paperback         2011

# %%
train_data['Edition type'].value_counts()
# Out:
# Paperback                5193
# Hardcover                 823
# Mass Market Paperback     155
# Sheet music                24
# Flexibound                 15
# Cards                       8
# Spiral-bound                4
# Tankobon Softcover          3
# Loose Leaf                  2
# Library Binding             1
# (French)Paperback           1
# Leather Bound               1
# (German)Paperback           1
# Board book                  1
# Product Bundle              1
# (Kannada)Paperback          1
# Perfect Paperback           1
# Plastic Comb                1
# (Spanish)Paperback          1
# Name: Edition type, dtype: int64

# %%
train_data.drop('Edition', axis=1, inplace=True)
test_data.drop('Edition', axis=1, inplace=True)
train_data.head()
# Out:
#    Reviews  Ratings                          BookCategory   Price  \
# 0      4.0      8.0                    Action & Adventure  220.00
# 1      3.0      1.0  Biographies, Diaries & True Accounts  202.93
# 2      4.0      6.0                                Humour  299.00
# 3      4.0      1.0             Crime, Thriller & Mystery  180.00
# 4      5.0      1.0              Arts, Film & Photography  965.62
#
#   Edition type Edition year
# 0    Paperback         2016
# 1    Paperback         2012
# 2    Paperback         1982
# 3    Paperback         2017
# 4    Hardcover         2006

# %%
train_data['BookCategory'].value_counts()
# Out:
# Action & Adventure                      818
# Crime, Thriller & Mystery               723
# Biographies, Diaries & True Accounts    596
# Language, Linguistics & Writing         594
# Comics & Mangas                         583
# Romance                                 560
# Humour                                  540
# Arts, Film & Photography                517
# Computing, Internet & Digital Media     510
# Sports                                  471
# Politics                                325
# Name: BookCategory, dtype: int64

# %%
train_data.dtypes
# Out:
# Reviews         float64
# Ratings         float64
# BookCategory     object
# Price           float64
# Edition type     object
# Edition year     object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20, 8))
sns.barplot(x=train_data['BookCategory'], y=train_data['Price'])
plt.xticks(rotation=90)
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(20, 8))
sns.barplot(x=train_data['Edition type'], y=train_data['Price'])
plt.xticks(rotation=90)
plt.plot()
# Out:
# []

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6237 entries, 0 to 6236
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Reviews       6237 non-null   float64
#  1   Ratings       6237 non-null   float64
#  2   BookCategory  6237 non-null   object
#  3   Price         6237 non-null   float64
#  4   Edition type  6237 non-null   object
#  5   Edition year  6237 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 292.5+ KB

# %% [markdown]
# Priinting the rows which does not contain digits in the edition year feature.

# %%
pd.set_option('display.max_rows', 50)
x = train_data[train_data['Edition year'].apply(lambda x: str(x).isalpha())]
x
# Out:
#       Reviews  Ratings                          BookCategory   Price  \
# 169       5.0      2.0                    Action & Adventure   418.0
# 235       3.0      6.0              Arts, Film & Photography  1453.0
# 582       4.0      7.0              Arts, Film & Photography   415.0
# 972       3.0      1.0                       Comics & Mangas   445.0
# 1233      5.0      1.0                    Action & Adventure   277.0
# 1558      5.0      1.0             Crime, Thriller & Mystery   100.0
# 1605      4.0      2.0       Language, Linguistics & Writing   399.0
# 1631      4.0      1.0                                Sports   709.0
# 1643      3.0      5.0              Arts, Film & Photography   220.0
# 1769      5.0      1.0   Computing, Internet & Digital Media  2248.0
# 2101      4.0      2.0       Language, Linguistics & Writing   798.0
# 2229      4.0      3.0  Biographies, Diaries & True Accounts   188.0
# 2660      4.0      2.0                    Action & Adventure   270.0
# 2779      5.0      4.0              Arts, Film & Photography   805.0
# 3511      5.0      3.0                       Comics & Mangas  1499.0
# 3875      3.0      7.0             Crime, Thriller & Mystery   896.0
# 3960      4.0      3.0  Biographies, Diaries & True Accounts   123.0
# 4036      5.0      1.0                                Sports  1826.0
# 4403      4.0      2.0              Arts, Film & Photography  1542.0
# 5117      3.0      5.0  Biographies, Diaries & True Accounts   180.0
# 5860      3.0      8.0       Language, Linguistics & Writing   127.0
#
#       Edition type Edition year
# 169      Paperback       Import
# 235   Plastic Comb         NTSC
# 582      Paperback       Import
# 972      Paperback       Import
# 1233     Paperback       Import
# 1558     Hardcover    Facsimile
# 1605     Paperback          set
# 1631     Paperback       Import
# 1643     Paperback      Edition
# 1769     Hardcover          set
# 2101     Hardcover   Unabridged
# 2229     Paperback        Print
# 2660     Paperback          set
# 2779     Paperback       Import
# 3511     Paperback          set
# 3875     Hardcover       Import
# 3960     Paperback    Audiobook
# 4036     Paperback       Import
# 4403     Hardcover       Import
# 5117     Paperback          set
# 5860     Paperback        Print

# %%
pd.set_option('display.max_rows', 50)
x1 = test_data[test_data['Edition year'].apply(lambda x: str(x).isalpha())]
x1
# Out:
#       Reviews  Ratings                         BookCategory Edition type  \
# 97        3.0      1.0                              Romance    Paperback
# 178       4.0      1.0                      Comics & Mangas    Paperback
# 396       5.0      2.0                             Politics    Paperback
# 579       3.0      1.0                             Politics    Hardcover
# 955       4.0      1.0                               Sports    Paperback
# 1179      4.0      3.0                      Comics & Mangas    Hardcover
# 1191      5.0      1.0                      Comics & Mangas    Paperback
# 1408      5.0      3.0                               Humour    Paperback
# 1541      3.0      1.0  Computing, Internet & Digital Media    Paperback
#
#      Edition year
# 97          Print
# 178   Illustrated
# 396         Print
# 579        Import
# 955         Print
# 1179          set
# 1191       Import
# 1408          set
# 1541       Import

# %% [markdown]
# We cannt drop those instances as we need the output od the same shape.
#
# Thefore filling a random values in those instances.

# %%
train_data = train_data[train_data['Edition year'].apply(lambda x: str(x).isdigit())]

# %% [markdown]
# New train data shape

# %%
train_data.shape
# Out:
# (6216, 6)

# %%
train_data['Edition year'] = train_data['Edition year'].astype('int64')

# %%
test_data.dtypes
# Out:
# Reviews         float64
# Ratings         float64
# BookCategory     object
# Edition type     object
# Edition year     object
# dtype: object

# %%
dummy_test_data = test_data
dummy_test_data = dummy_test_data[dummy_test_data['Edition year'].apply(lambda x: str(x).isdigit())]

# %%
Max = dummy_test_data['Edition year'].max()
Min = dummy_test_data['Edition year'].min()

# %%
import random 
test_data['Edition year'] = test_data['Edition year'].apply(
    lambda x: str(x) if str(x).isdigit() else random.randint(int(Min), int(Max)))
test_data['Edition year'] = test_data['Edition year'].astype('int64')

# %%
train_data['Edition year'].corr(train_data.Price)
# Out:
# -0.0248136947601535

# %%
train_data.corr()
# Out:
#                Reviews   Ratings     Price  Edition year
# Reviews       1.000000 -0.127613  0.134032      0.006040
# Ratings      -0.127613  1.000000 -0.061427      0.020141
# Price         0.134032 -0.061427  1.000000     -0.024814
# Edition year  0.006040  0.020141 -0.024814      1.000000

# %%
train_data.head()
train_data = train_data[['Reviews',	'Ratings',	'BookCategory',	'Edition type',	'Edition year',	'Price']]
train_data.head(10)
# Out:
#    Reviews  Ratings                          BookCategory Edition type  \
# 0      4.0      8.0                    Action & Adventure    Paperback
# 1      3.0      1.0  Biographies, Diaries & True Accounts    Paperback
# 2      4.0      6.0                                Humour    Paperback
# 3      4.0      1.0             Crime, Thriller & Mystery    Paperback
# 4      5.0      1.0              Arts, Film & Photography    Hardcover
# 5      4.0      8.0                                Sports    Paperback
# 6      4.0      7.0             Crime, Thriller & Mystery    Paperback
# 7      4.0      1.0                                Sports    Hardcover
# 8      4.0      1.0  Biographies, Diaries & True Accounts    Paperback
# 9      4.0      1.0                    Action & Adventure    Paperback
#
#    Edition year   Price
# 0          2016  220.00
# 1          2012  202.93
# 2          1982  299.00
# 3          2017  180.00
# 4          2006  965.62
# 5          2009  900.00
# 6          2017  224.00
# 7          2018  836.00
# 8          2015  130.00
# 9          2013  695.00

# %%
# checking if the label encoding can be done
set(train_data['BookCategory'])==set(test_data['BookCategory'])
# Out:
# True

# %%
set(train_data['Edition type'])==set(test_data['Edition type'])
# Out:
# False

# %%
train_data['Edition type'].value_counts()
# Out:
# Paperback                5178
# Hardcover                 818
# Mass Market Paperback     155
# Sheet music                24
# Flexibound                 15
# Cards                       8
# Spiral-bound                4
# Tankobon Softcover          3
# Loose Leaf                  2
# Perfect Paperback           1
# Board book                  1
# (Kannada)Paperback          1
# Product Bundle              1
# Library Binding             1
# (German)Paperback           1
# Leather Bound               1
# (French)Paperback           1
# (Spanish)Paperback          1
# Name: Edition type, dtype: int64

# %%
test_data['Edition type'].value_counts()
# Out:
# Paperback                1265
# Hardcover                 233
# Mass Market Paperback      45
# Sheet music                 8
# Flexibound                  4
# Spiral-bound                2
# Cards                       1
# (Chinese)Paperback          1
# Loose Leaf                  1
# Name: Edition type, dtype: int64

# %%
train_data['Edition type'] = train_data['Edition type'].replace(['Tankobon Softcover',
                                                                 'Loose Leaf',
                                                                 'Board book',
                                                                 'Leather Bound',
                                                                 'Product Bundle',
                                                                 'Library Binding'], 'Rare')
train_data['Edition type'] = train_data['Edition type'].replace(['Perfect Paperback',
                                                                 '(German)Paperback',
                                                                 '(Kannada)Paperback',
                                                                 '(French)Paperback',
                                                                 '(Spanish)Paperback'], 'Paperback')
train_data['Edition type'].value_counts()
# Out:
# Paperback                5183
# Hardcover                 818
# Mass Market Paperback     155
# Sheet music                24
# Flexibound                 15
# Rare                        9
# Cards                       8
# Spiral-bound                4
# Name: Edition type, dtype: int64

# %%
test_data['Edition type'] = test_data['Edition type'].replace(['Loose Leaf'], 'Rare')
test_data['Edition type'] = test_data['Edition type'].replace(['(Chinese)Paperback'], 'Paperback')
test_data['Edition type'].value_counts()
# Out:
# Paperback                1266
# Hardcover                 233
# Mass Market Paperback      45
# Sheet music                 8
# Flexibound                  4
# Spiral-bound                2
# Cards                       1
# Rare                        1
# Name: Edition type, dtype: int64

# %%
set(train_data['Edition type'])==set(test_data['Edition type'])
# Out:
# True

# %% [markdown]
# Thus the label encoding of both the object features can be done.

# %%
print(train_data.dtypes)

from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()
train_data['BookCategory'] = labelencoder.fit_transform(train_data['BookCategory'])
test_data['BookCategory'] = labelencoder.transform(test_data['BookCategory'])

train_data['Edition type'] = labelencoder.fit_transform(train_data['Edition type'])
test_data['Edition type'] = labelencoder.transform(test_data['Edition type'])

print(train_data.head())
# Out:
# Reviews         float64
# Ratings         float64
# BookCategory     object
# Edition type     object
# Edition year      int64
# Price           float64
# dtype: object
#    Reviews  Ratings  BookCategory  Edition type  Edition year   Price
# 0      4.0      8.0             0             4          2016  220.00
# 1      3.0      1.0             2             4          2012  202.93
# 2      4.0      6.0             6             4          1982  299.00
# 3      4.0      1.0             5             4          2017  180.00
# 4      5.0      1.0             1             2          2006  965.62

# %%
from sklearn.model_selection import train_test_split

array = train_data.values
X = array[:, 0:5]
Y = array[:, 5]

#X = train_data.drop('Price', axis=1)
#Y = train_data['Price'].values
x_train, x_valid, y_train, y_valid = train_test_split(X, Y, test_size=0.20, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_absolute_error

# Spot check algorithms
models = []
models.append(('LR', LinearRegression()))
models.append(('LA', Lasso()))
models.append(('EN', ElasticNet()))

models.append(('KNR', KNeighborsRegressor()))
models.append(('RFR', RandomForestRegressor()))


from sklearn.metrics import mean_absolute_error

# Evaluate each model
results = []
names = []
for name, model in models:
  model.fit(x_train, y_train)
  predictions = model.predict(x_valid)
  cv_results = mean_absolute_error(y_valid, predictions)
  results.append(cv_results)
  names.append(name)
  msg = '%s : %f '% (name, cv_results)
  print(msg)
# Out:
# LR : 359.190061
# LA : 359.157673
# EN : 361.426859
# KNR : 362.543785
# RFR : 359.579665

# %%
# Final model
knn = KNeighborsRegressor()
knn.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# Predictions on the test data

# %%
test_data.head()
# Out:
#    Reviews  Ratings  BookCategory  Edition type  Edition year
# 0      4.0      9.0             5             3          1986
# 1      5.0      1.0             4             4          2018
# 2      5.0      4.0             9             4          2011
# 3      4.0      1.0             4             4          2016
# 4      4.0      9.0             7             4          2011

# %%
predictions = knn.predict(test_data)

# %%
#from google.colab import files
#uploaded = files.upload()

# %%
#sub = pd.read_excel('Sample_Submission.xlsx')
#sub

# %%
np.set_printoptions(precision=2)
df = pd.DataFrame({'Price':predictions})

# %%
df.to_csv('Predictions.csv', index=False)

# %%
p = pd.read_csv('Predictions.csv')
p
# Out:
#          Price
# 0      442.890
# 1      704.200
# 2      357.448
# 3     1355.400
# 4      395.288
# ...        ...
# 1555   595.030
# 1556   290.786
# 1557   359.998
# 1558   459.600
# 1559   429.400
#
# [1560 rows x 1 columns]
